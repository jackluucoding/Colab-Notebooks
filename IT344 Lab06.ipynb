# %%
from sklearn import datasets

import pandas as pd

iris = pd.read_csv("https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv")
iris = datasets.load_iris()
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()

y_pred = gnb.fit(iris.data, iris.target).predict(iris.data)

print("Number of mislabled points out of total %d points:%d "% (iris.data.shape[0], (iris.target != y_pred).sum()))
print(pd.crosstab(gnb.predict(iris.data), iris.target))
# Out:
# Number of mislabled points out of total 150 points:6
# col_0   0   1   2
# row_0
# 0      50   0   0
# 1       0  47   3
# 2       0   3  47
