# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f0ac46be-c9be-4f78-b9f5-05cc2562d4c3" name="files[]" multiple disabled />
#      <output id="result-f0ac46be-c9be-4f78-b9f5-05cc2562d4c3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving tips.csv to tips.csv

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['tips.csv']))

# %%
import numpy as np
from matplotlib import pyplot as plt

fig = plt.figure()
#ax1 = fig.add_subplot(2,2,1)
#ax1.hist(df['tip'], bins=10,alpha=0.3,color='g')

ax2 = fig.add_subplot(2,2,2)

grouped = df.groupby(df['day']) 

#ax2 = grouped.keys.value_counts()


#.plot(kind='bar',rot=360)

ax2=ax2.hist()
ax2.set_ylim([0,100])


#ax3 = fig.add_subplot(2,2,3)
#df['tip'].plot.box()
#ax4 = fig.add_subplot(2,2,4)
#df['size'].hist()
#g2 = df['smoker'].groupby(df['smoker'])
# ax5 = plt.figure().add_subplot(1,1,1)
# df2 = g2.value_counts()
# df2.index = ['No','Yes']
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: Tried to set a label via parameter 'x' in func 'hist' but couldn't find such an argument.
# (This is a programming error, please report to the Matplotlib list!)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-e0ab283f4606> in <module>()
#      15 #.plot(kind='bar',rot=360)
#      16
# ---> 17 ax2=ax2.hist()
#      18 ax2.set_ylim([0,100])
#      19
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ...
