# %%
import pandas as pd

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1062578b-def0-45fa-8586-dc1454d6c77d" name="files[]" multiple disabled />
#      <output id="result-1062578b-def0-45fa-8586-dc1454d6c77d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving tips.csv to tips (1).csv

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['tips.csv']))

# %%
import numpy as np
from matplotlib import pyplot as plt

df = pd.read_csv('tips.csv')
fig = plt.figure()

ax2 = fig.add_subplot(2,2,2)
grouped = df['day'].groupby(df['day'])

grouped.hist()



#ax3 = fig.add_subplot(2,2,3)
#df['tip'].plot.box()
#ax4 = fig.add_subplot(2,2,4)
#df['size'].hist()
#g2 = df['smoker'].groupby(df['smoker'])
#ax5 = plt.figure().add_subplot(1,1,1)
#df2 = g2.value_counts()
#df2.index = ['No','Yes']
#df2.plot.pie()
# Out:
# day
# Fri     AxesSubplot(0.547727,0.536818;0.352273x0.343182)
# Sat     AxesSubplot(0.547727,0.536818;0.352273x0.343182)
# Sun     AxesSubplot(0.547727,0.536818;0.352273x0.343182)
# Thur    AxesSubplot(0.547727,0.536818;0.352273x0.343182)
# Name: day, dtype: object
